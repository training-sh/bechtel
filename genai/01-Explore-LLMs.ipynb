# %%
 # %pip install transformers==4.53.0 torch
 dbutils.library.restartPython()
# Out:
# Collecting transformers==4.53.0
#   Downloading transformers-4.53.0-py3-none-any.whl.metadata (39 kB)
# Requirement already satisfied: torch in /opt/databricks-environments/databricks-ai/lib/python3.12/site-packages (2.9.0+cu129)
# Requirement already satisfied: filelock in /opt/databricks-environments/databricks-ai/lib/python3.12/site-packages (from transformers==4.53.0) (3.17.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.30.0 in /opt/databricks-environments/databricks-ai/lib/python3.12/site-packages (from transformers==4.53.0) (0.34.4)
# Requirement already satisfied: numpy>=1.17 in /opt/databricks-environments/databricks-ai/lib/python3.12/site-packages (from transformers==4.53.0) (2.1.3)
# Requirement already satisfied: packaging>=20.0 in /opt/databricks-environments/databricks-ai/lib/python3.12/site-packages (from transformers==4.53.0) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /opt/databricks-environments/databricks-ai/lib/python3.12/site-packages (from transformers==4.53.0) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /opt/databricks-environments/databricks-ai/lib/python3.12/site-packages (from transformers==4.53.0) (2024.11.6)
# Requirement already satisfied: requests in /opt/databricks-environments/databricks-ai/lib/python3.12/site-packages (from transformers==4.53.0) (2.32.5)
# Collecting tokenizers<0.22,>=0.21 (from transformers==4.53.0)
#   Downloading tokenizers-0.21.4-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: safetensors>=0.4.3 in /opt/databricks-environments/databricks-ai/lib/python3.12/site-packages (from transformers==4.53.0) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in /opt/databricks-environments/databricks-ai/lib/python3.12/site-packages (from transformers==4.53.0) (4.67.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /opt/databricks-environments/databricks-ai/lib/python3.12/site-packages (from torch) (4.14.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch) (78.1.1)
# Requirement already satisfied: sympy>=1.13.3 in /opt/databricks-environments/databricks-ai/lib/python3.12/site-packages (from torch) (1.13.3)
# Requirement already satisfied: networkx>=2.5.1 in /opt/databricks-environments/databricks-ai/lib/python3.12/site-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /opt/databricks-environments/databricks-ai/lib/python3.12/site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /opt/databricks-environments/databricks-ai/lib/python3.12/site-packages (from torch) (2023.5.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.9.86 in /opt/databricks-environments/databricks-ai/lib/python3.12/site-packages (from torch) (12.9.86)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.9.79 in /opt/databricks-environments/databricks-ai/lib/python3.12/site-packages (from torch) (12.9.79)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.9.79 in /opt/databricks-environments/databricks-ai/lib/python3.12/site-packages (from torch) (12.9.79)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /opt/databricks-environments/databricks-ai/lib/python3.12/site-packages (from torch) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.9.1.4 in /opt/databricks-environments/databricks-ai/lib/python3.12/site-packages (from torch) (12.9.1.4)
# Requirement already satisfied: nvidia-cufft-cu12==11.4.1.4 in /opt/databricks-environments/databricks-ai/lib/python3.12/site-packages (from torch) (11.4.1.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.10.19 in /opt/databricks-environments/databricks-ai/lib/python3.12/site-packages (from torch) (10.3.10.19)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.5.82 in /opt/databricks-environments/databricks-ai/lib/python3.12/site-packages (from torch) (11.7.5.82)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.10.65 in /opt/databricks-environments/databricks-ai/lib/python3.12/site-packages (from torch) (12.5.10.65)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /opt/databricks-environments/databricks-ai/lib/python3.12/site-packages (from torch) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /opt/databricks-environments/databricks-ai/lib/python3.12/site-packages (from torch) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /opt/databricks-environments/databricks-ai/lib/python3.12/site-packages (from torch) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.9.79 in /opt/databricks-environments/databricks-ai/lib/python3.12/site-packages (from torch) (12.9.79)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.9.86 in /opt/databricks-environments/databricks-ai/lib/python3.12/site-packages (from torch) (12.9.86)
# Requirement already satisfied: nvidia-cufile-cu12==1.14.1.1 in /opt/databricks-environments/databricks-ai/lib/python3.12/site-packages (from torch) (1.14.1.1)
# Requirement already satisfied: triton==3.5.0 in /opt/databricks-environments/databricks-ai/lib/python3.12/site-packages (from torch) (3.5.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /opt/databricks-environments/databricks-ai/lib/python3.12/site-packages (from huggingface-hub<1.0,>=0.30.0->transformers==4.53.0) (1.2.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/databricks-environments/databricks-ai/lib/python3.12/site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/databricks-environments/databricks-ai/lib/python3.12/site-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/databricks-environments/databricks-ai/lib/python3.12/site-packages (from requests->transformers==4.53.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/databricks-environments/databricks-ai/lib/python3.12/site-packages (from requests->transformers==4.53.0) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/databricks-environments/databricks-ai/lib/python3.12/site-packages (from requests->transformers==4.53.0) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/databricks-environments/databricks-ai/lib/python3.12/site-packages (from requests->transformers==4.53.0) (2025.4.26)
# Downloading transformers-4.53.0-py3-none-any.whl (10.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.8/10.8 MB 109.9 MB/s eta 0:00:00
# Downloading tokenizers-0.21.4-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 76.6 MB/s eta 0:00:00
# Installing collected packages: tokenizers, transformers
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.22.1
#     Not uninstalling tokenizers at /opt/databricks-environments/databricks-ai/lib/python3.12/site-packages, outside environment /local_disk0/.ephemeral_nfs/envs/pythonEnv-36da6968-a319-4d2f-9031-025bbb84b378
#     Can't uninstall 'tokenizers'. No files were found to uninstall.
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.57.1
#     Not uninstalling transformers at /opt/databricks-environments/databricks-ai/lib/python3.12/site-packages, outside environment /local_disk0/.ephemeral_nfs/envs/pythonEnv-36da6968-a319-4d2f-9031-025bbb84b378
#     Can't uninstall 'transformers'. No files were found to uninstall.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# trl 0.23.0 requires transformers>=4.56.1, but you have transformers 4.53.0 which is incompatible.
# unsloth 2025.11.3 requires transformers!=4.52.0,!=4.52.1,!=4.52.2,!=4.52.3,!=4.53.0,!=4.54.0,!=4.55.0,!=4.55.1,!=4.57.0,<=4.57.2,>=4.51.3, but you have transformers 4.53.0 which is incompatible.
# unsloth-zoo 2026.1.2 requires transformers!=4.52.0,!=4.52.1,!=4.52.2,!=4.52.3,!=4.53.0,!=4.54.0,!=4.55.0,!=4.55.1,<=4.57.3,>=4.51.3, but you have transformers 4.53.0 which is incompatible.
# vllm 0.13.0 requires transformers<5,>=4.56.0, but you have transformers 4.53.0 which is incompatible.
# Successfully installed tokenizers-0.21.4 transformers-4.53.0
# Note: you may need to restart the kernel using %restart_python or dbutils.library.restartPython() to use updated packages.

# %%
from transformers import pipeline
# pt = PyTorch
# tf = Tensor Flow
# about 500 MB
summarizer = pipeline(
    "summarization",
    model="sshleifer/distilbart-cnn-6-6",
    framework="pt"
)
# Out:
# Skipping import of cpp extensions due to incompatible torch version 2.9.0+cu129 for torchao version 0.15.0+cu129             Please see https://github.com/pytorch/ao/issues/2919 for more info
# config.json: 0.00B [00:00, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/460M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/460M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# Device set to use cuda:0

# %%
import os
from transformers import pipeline

os.environ["HF_HOME"] = "/Volumes/workspace/default/llms"
os.environ["TRANSFORMERS_CACHE"] = "/Volumes/workspace/default/llms"
# Out:
# Skipping import of cpp extensions due to incompatible torch version 2.9.0+cu129 for torchao version 0.15.0+cu129             Please see https://github.com/pytorch/ao/issues/2919 for more info

# %%
# pt = PyTorch
# tf = Tensor Flow
summarizer = pipeline(
    "summarization",
    model="sshleifer/distilbart-cnn-6-6",
    framework="pt"
)
# Out:
# config.json: 0.00B [00:00, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/460M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/460M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# Device set to use cuda:0

# %%
 text = "Large language models (LLMs) are advanced AI systems capable of understanding and generating human-like text by learning from vast datasets. These models, which include OpenAI's GPT series and Google's BERT, have transformed the field of natural language processing (NLP). They are designed to perform a wide range of tasks, from translation and summarization to question-answering and creative writing. The development of LLMs has been a significant milestone in AI, enabling machines to handle complex language tasks with increasing sophistication. As they evolve, LLMs continue to push the boundaries of what's possible in machine learning and artificial intelligence, offering exciting prospects for the future of technology."
 summary = summarizer(text, max_length=75, min_length=25, do_sample=False)
 print(summary)
# Out:
# [{'summary_text': ' Large language models (LLMs) are advanced AI systems capable of understanding and generating human-like text by learning from vast datasets . These models have transformed the field of natural language processing (NLP) They are designed to perform a wide range of tasks, from translation and summarization to question-answering and creative writing.'}]

# %%
 summary = summarizer("this movie is good to be wathced only if you have strong heart", max_length=75, min_length=25, do_sample=False)
 print(summary)
# Out:
# Your max_length is set to 75, but your input_length is only 17. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=8)
# [{'summary_text': ' This movie is good to be wathced only if you have a strong heart . This movie will be a great movie if you are strong enough to take part in it .'}]

# %%
from transformers import pipeline

sentiment_analyzer = pipeline(
    "sentiment-analysis",
    model="distilbert/distilbert-base-uncased-finetuned-sst-2-english",
    framework="pt",
    # cache_dir="/Volumes/workspace/default/llms"
)
# Out:
# Device set to use cuda:0

# %%
text = "The product is terrible. I want a refund."

result = sentiment_analyzer(text)

print(result)
# Out:
# [{'label': 'NEGATIVE', 'score': 0.9997866749763489}]

# %%
from transformers import pipeline

translator = pipeline(
    "translation_en_to_fr",
    model="google-t5/t5-small",
    framework="pt" 
)
# Out:
# Device set to use cuda:0

# %%
text = "Hello, how are you?"
translation = translator(text)
print(translation)
# Out:
# [{'translation_text': 'Bonjour, comment êtes-vous ?'}]

# %%
from transformers import pipeline

classifier = pipeline(
    "zero-shot-classification",
    model="cross-encoder/nli-MiniLM2-L6-H768",
    framework="pt" 
)
# Out:
# config.json:   0%|          | 0.00/875 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/328M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/330 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# Device set to use cuda:0

# %%
 text = "Azure Databricks is a powerful platform for big data analytics."
 labels = ["technology", "health", "finance"]
 classification = classifier(text, candidate_labels=labels)
 print(classification)
# Out:
# {'sequence': 'Azure Databricks is a powerful platform for big data analytics.', 'labels': ['technology', 'health', 'finance'], 'scores': [0.9843654036521912, 0.00849845353513956, 0.007136165630072355]}

# %%
from transformers import pipeline

# Load the summarization model with PyTorch weights
summarizer = pipeline("summarization", model="facebook/bart-large-cnn", framework="pt")

# Load the sentiment analysis model
sentiment_analyzer = pipeline("sentiment-analysis", model="distilbert/distilbert-base-uncased-finetuned-sst-2-english", revision="714eb0f")

# Load the translation model
translator = pipeline("translation_en_to_fr", model="google-t5/t5-base", revision="a9723ea")

# Load a general purpose model for zero-shot classification and few-shot learning
classifier = pipeline("zero-shot-classification", model="facebook/bart-large-mnli", revision="d7645e1")
